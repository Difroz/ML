# %%
import numpy as np
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import KFold, cross_val_score
from sklearn.preprocessing import scale
from sklearn.datasets import load_boston

# %%
X, y = load_boston(return_X_y=True)
X_sc = scale(X)

# %%
kf = KFold(shuffle=True,random_state=42)
result = {}

# %%
for p in np.linspace(1,10, num=200):
    neigh = KNeighborsRegressor(weights='distance',p=p)
    score = cross_val_score(neigh, X_sc, y, cv=kf, scoring='neg_mean_squared_error')
    result[round(p, 2)] = round(score.mean(), 1)

# %%
result
# Out:
# {1.0: -16.0,
#  1.05: -16.4,
#  1.09: -16.4,
#  1.14: -16.4,
#  1.18: -16.5,
#  1.23: -16.5,
#  1.27: -16.6,
#  1.32: -16.8,
#  1.36: -16.9,
#  1.41: -17.1,
#  1.45: -17.1,
#  1.5: -17.0,
#  1.54: -17.1,
#  1.59: -16.8,
#  1.63: -17.0,
#  1.68: -17.0,
#  1.72: -17.2,
#  1.77: -17.2,
#  1.81: -17.2,
#  1.86: -17.3,
#  1.9: -17.4,
#  1.95: -17.4,
#  1.99: -17.3,
#  2.04: -17.3,
#  2.09: -17.4,
#  2.13: -17.7,
#  2.18: -17.6,
#  2.22: -17.3,
#  2.27: -17.5,
#  2.31: -17.6,
#  2.36: -17.6,
#  2.4: -17.6,
#  2.45: -17.6,
#  2.49: -17.3,
#  2.54: -17.3,
#  2.58: -17.5,
#  2.63: -17.5,
#  2.67: -17.5,
#  2.72: -17.5,
#  2.76: -17.5,
#  2.81: -17.6,
#  2.85: -17.6,
#  2.9: -17.7,
#  2.94: -17.9,
#  2.99: -17.9,
#  3.04: -18.1,
#  3.08: -18.1,
#  3.13: -18.2,
#  3.17: -18.3,
#  3.22: -18.3,
#  3.26: -18.3,
#  3.31: -18.2,
#  3.35: -18.5,
#  3.4: -18.5,
#  3.44: -18.6,
#  3.49: -18.6,
#  3.53: -18.9,
#  3.58: -18.9,
#  3.62: -18.9,
#  3.67: -18.9,
#  3.71: -18.9,
#  3.76: -18.9,
#  3.8: -19.0,
#  3.85: -19.1,
#  3.89: -19.0,
#  3.94: -19.1,
#  3.98: -19.2,
#  4.03: -19.2,
#  4.08: -19.1,
#  4.12: -19.1,
#  4.17: -19.1,
#  4.21: -19.1,
#  4.26: -19.3,
#  4.3: -19.3,
#  4.35: -19.3,
#  4.39: -19.3,
#  4.44: -19.2,
#  4.48: -19.2,
#  4.53: -19.2,
#  4.57: -19.4,
#  4.62: -19.5,
#  4.66: -19.5,
#  4.71: -19.6,
#  4.75: -19.7,
#  4.8: -19.7,
#  4.84: -19.7,
#  4.89: -19.7,
#  4.93: -19.7,
#  4.98: -19.8,
#  5.03: -19.7,
#  5.07: -19.7,
