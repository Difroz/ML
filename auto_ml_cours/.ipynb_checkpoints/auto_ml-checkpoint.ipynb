# %%
import os
# Installed libraries
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
# Imports from LightAutoML package
from lightautoml.automl.presets.tabular_presets import TabularAutoML, TabularUtilizedAutoML
from lightautoml.tasks import Task

# %%
os.listdir()
# Out:
# ['test_data.csv',
#  'sample_submission.csv',
#  'train_data.csv',
#  '.ipynb_checkpoints',
#  'submis_automl.csv',
#  'auto_ml.ipynb',
#  'gbmodel.ipynb']

# %%
df_train = pd.read_csv('train_data.csv', index_col='row_ID')
df_train.head()
# Out:
#        vehicle_manufacturer vehicle_model vehicle_category  current_mileage  \
# row_ID
# 0                    TOYOTA        Aqua s            Sedan           133000
# 1             MERCEDES-BENZ         C 220            Sedan            24500
# 2                   HYUNDAI      Veloster        Hatchback            31000
# 3                   HYUNDAI      Santa FE             Jeep           115459
# 4                    TOYOTA           CHR             Jeep            18950
#
#         vehicle_year vehicle_gearbox_type doors_cnt                 wheels  \
# row_ID
# 0               2014            Automatic       4/5    Right-hand drive
# 1               2010               Manual       4/5           Left wheel
# 2               2016            Tiptronic       2/3           Left wheel
# 3               2015            Automatic       4/5           Left wheel
# 4               2019            Automatic       4/5           Left wheel
#
#        vehicle_color vehicle_interior_color              car_vin  \
# row_ID
# 0            Silver                  Black                   NaN
# 1            Silver                  Black                   NaN
# 2            Silver                  Black    KMHTC6AE3GU293912
# 3              Blue                  Black                   NaN
# 4             Black                     NaN   JTNKHMBX7K1030253
#
#         car_leather_interior deal_type  final_price
# row_ID
# 0                          0  For Sale       3650.0
# 1                          0  For Sale       6800.0
# 2                          1  For Sale       6300.0
# 3                          1  For Sale      14488.0
# 4                          1  For Sale       5000.0

# %%
df_test = pd.read_csv('test_data.csv', index_col='row_ID')
df_test.head()
# Out:
#        vehicle_manufacturer vehicle_model vehicle_category  current_mileage  \
# row_ID
# 35000                TOYOTA         Prius        Hatchback           323733
# 35001               HYUNDAI       Elantra            Sedan           112000
# 35002                 LEXUS        NX 300             Jeep            16920
# 35003                 LEXUS       CT 200h        Hatchback           302742
# 35004                TOYOTA         RAV 4             Jeep             1800
#
#         vehicle_year vehicle_gearbox_type doors_cnt          wheels  \
# row_ID
# 35000           2012            Automatic       4/5    Left wheel
# 35001           2013            Tiptronic       4/5    Left wheel
# 35002           2018            Automatic       NaN    Left wheel
# 35003           2012            Automatic       4/5    Left wheel
# 35004           2002               Manual       4/5    Left wheel
#
#        vehicle_color vehicle_interior_color              car_vin  \
# row_ID
# 35000          Grey                  Black    JTDKN3DU6C5439638
# 35001          Grey                  Black            SURATSHIA
# 35002         Brown                     NaN   JTJYARBZ5J2104521
# 35003         White                     NaN   JTHKD5BH4C2070945
# 35004        Silver                  Black                   NaN
#
#         car_leather_interior deal_type
# row_ID
# 35000                      1  For Sale
# 35001                      1  For Sale
# 35002                      1  For Sale
# 35003                      1  For Sale
# 35004                      0  For Sale

# %%
df_train.drop_duplicates(inplace=True)

# %%
X_train, X_valid = train_test_split(df_train, train_size=0.7)

# %%
task = Task('reg', metric='mae')

# %%
roles = {'target': 'final_price'}

# %%
automl = TabularUtilizedAutoML(task=task, 
                               timeout=600, 
                               cpu_limit=4, 
                               general_params={'use_algos':[['linear_l2','lgb', 'lgb_tuned']]})

# %%
oof_pred = automl.fit_predict(df_train, roles = roles)
# Out:
# Current random state: {'reader_params': {'random_state': 42}, 'general_params': {'return_all_predictions': False}}
# Found general_params in kwargs, need to combine
# Merged variant for general_params = {'use_algos': [['linear_l2', 'lgb', 'lgb_tuned']], 'return_all_predictions': False}
# Start automl preset with listed constraints:
# - time: 599.9959371089935 seconds
# - cpus: 4 cores
# - memory: 16 gb
#
# Train data shape: (35000, 14)
# Feats was rejected during automatic roles guess: []
#
#
# Layer 1 ...
# Train process start. Time left 594.4650325775146 secs
# Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -4604.436595153808
# Linear model: C = 5e-05 score = -4604.431616908482
# Linear model: C = 0.0001 score = -4604.4266572658
# Linear model: C = 0.0005 score = -4604.4217105669295
# Linear model: C = 0.001 score = -4604.416768319266
# Linear model: C = 0.005 score = -5239.2725096261165
# Linear model: C = 0.01 score = -5239.268966761998
#
# ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -5613.848128097534
# Linear model: C = 5e-05 score = -5613.844804890224
# Linear model: C = 0.0001 score = -5613.84149293954
# Linear model: C = 0.0005 score = -5613.838195975168
# Linear model: C = 0.001 score = -5613.8348872746055
# Linear model: C = 0.005 score = -6573.823240495954
# Linear model: C = 0.01 score = -6573.822929007394
#
# ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -4039.933055472238
# Linear model: C = 5e-05 score = -4039.9307486092703
# Linear model: C = 0.0001 score = -4039.928483428955
# Linear model: C = 0.0005 score = -4039.926203739711
# Linear model: C = 0.001 score = -4039.9239230128696
# Linear model: C = 0.005 score = -4039.9216695861815
# Linear model: C = 0.01 score = -4039.919418282645
# Linear model: C = 0.05 score = -4039.9171338413785
# Linear model: C = 0.1 score = -4039.9149178510393
# Linear model: C = 0.5 score = -4039.9126105913433
# Linear model: C = 1 score = -4039.910324659075
# Linear model: C = 5 score = -4687.00206539481
# Linear model: C = 10 score = -4687.003892578125
#
# ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -4031.145749986921
# Linear model: C = 5e-05 score = -4031.1432957502093
# Linear model: C = 0.0001 score = -4031.1408884102957
# Linear model: C = 0.0005 score = -4031.138545449393
# Linear model: C = 0.001 score = -4031.136179482596
# Linear model: C = 0.005 score = -4031.1338215637206
# Linear model: C = 0.01 score = -4031.1314903041293
# Linear model: C = 0.05 score = -4031.129131365095
# Linear model: C = 0.1 score = -4031.1268001360213
# Linear model: C = 0.5 score = -4031.124396035331
# Linear model: C = 1 score = -4031.1220559125627
# Linear model: C = 5 score = -4031.119747471401
# Linear model: C = 10 score = -4031.1173769356865
# Linear model: C = 50 score = -4031.1150624782017
# Linear model: C = 100 score = -4031.11268851144
# Linear model: C = 500 score = -4735.26016531808
# Linear model: C = 1000 score = -4735.256710344587
#
# ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -5255.290292479853
# Linear model: C = 5e-05 score = -3611.0312594958714
# Linear model: C = 0.0001 score = -3611.030316708156
# Linear model: C = 0.0005 score = -3611.0292849622456
# Linear model: C = 0.001 score = -3611.0282519493103
# Linear model: C = 0.005 score = -4187.555687935966
# Linear model: C = 0.01 score = -4187.556948695592
# Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# Time left 587.5056347846985
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2999.56
# [200]	valid's l1: 3138.93
# [300]	valid's l1: 3226.98
# Early stopping, best iteration is:
# [117]	valid's l1: 2970.23
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 4965.41
# [200]	valid's l1: 5300.2
# [300]	valid's l1: 5587.2
# Early stopping, best iteration is:
# [118]	valid's l1: 4944.86
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2452.54
# [200]	valid's l1: 2479.35
# [300]	valid's l1: 2548.83
# Early stopping, best iteration is:
# [110]	valid's l1: 2430.99
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2422.91
# [200]	valid's l1: 2578.14
# [300]	valid's l1: 2743
# Early stopping, best iteration is:
# [119]	valid's l1: 2388.23
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2916.45
# [200]	valid's l1: 3099.56
# Early stopping, best iteration is:
# [79]	valid's l1: 2874.93
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Optuna may run 502.5257582902908 secs
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 3099.66
# [200]	valid's l1: 3697.27
# Early stopping, best iteration is:
# [96]	valid's l1: 3038
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 3153.23
# [200]	valid's l1: 3623.14
# Early stopping, best iteration is:
# [95]	valid's l1: 3111.2
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2896.85
# [200]	valid's l1: 2975.03
# [300]	valid's l1: 3046.46
# Early stopping, best iteration is:
# [121]	valid's l1: 2871.8
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 3132.5
# [200]	valid's l1: 3574.39
# Early stopping, best iteration is:
# [96]	valid's l1: 3067.62
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 3092.06
# [200]	valid's l1: 3355.24
# Early stopping, best iteration is:
# [96]	valid's l1: 3047.11
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 3117.44
# [200]	valid's l1: 3308.04
# [300]	valid's l1: 3424.17
# Early stopping, best iteration is:
# [121]	valid's l1: 3080.19
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 3326.65
# [200]	valid's l1: 3777.54
# Early stopping, best iteration is:
# [77]	valid's l1: 3264.65
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 3357.83
# [200]	valid's l1: 3842.47
# Early stopping, best iteration is:
# [96]	valid's l1: 3318.5
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 3098.83
# [200]	valid's l1: 3468.55
# Early stopping, best iteration is:
# [97]	valid's l1: 3058.68
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2989.63
# [200]	valid's l1: 3244.15
# [300]	valid's l1: 3431.14
# Early stopping, best iteration is:
# [120]	valid's l1: 2968.9
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2827.01
# [200]	valid's l1: 2828.41
# [300]	valid's l1: 2875.52
# Early stopping, best iteration is:
# [124]	valid's l1: 2804.3
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2819.65
# [200]	valid's l1: 2812.82
# [300]	valid's l1: 2860.35
# Early stopping, best iteration is:
# [126]	valid's l1: 2802.64
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2808.71
# [200]	valid's l1: 2781.65
# [300]	valid's l1: 2837.11
# Early stopping, best iteration is:
# [134]	valid's l1: 2771.38
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2811.47
# [200]	valid's l1: 2835.08
# [300]	valid's l1: 2912.8
# Early stopping, best iteration is:
# [121]	valid's l1: 2793.03
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2866.01
# [200]	valid's l1: 3132.37
# Early stopping, best iteration is:
# [96]	valid's l1: 2846.64
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2891.26
# [200]	valid's l1: 3073.04
# Early stopping, best iteration is:
# [98]	valid's l1: 2881.84
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2813.16
# [200]	valid's l1: 2966.52
# [300]	valid's l1: 3084.67
# Early stopping, best iteration is:
# [111]	valid's l1: 2801.94
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2966.57
# [200]	valid's l1: 3204.68
# Early stopping, best iteration is:
# [93]	valid's l1: 2951.39
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 3214.18
# [200]	valid's l1: 3748.15
# Early stopping, best iteration is:
# [78]	valid's l1: 3162.57
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2959.5
# [200]	valid's l1: 3149.51
# [300]	valid's l1: 3285.66
# Early stopping, best iteration is:
# [116]	valid's l1: 2950.07
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2800
# [200]	valid's l1: 2829.58
# [300]	valid's l1: 2884.88
# Early stopping, best iteration is:
# [124]	valid's l1: 2791.51
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2799.38
# [200]	valid's l1: 2832.91
# [300]	valid's l1: 2896.72
# Early stopping, best iteration is:
# [155]	valid's l1: 2789.38
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2798.72
# [200]	valid's l1: 2840.68
# [300]	valid's l1: 2915.76
# Early stopping, best iteration is:
# [108]	valid's l1: 2787.12
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2783.77
# [200]	valid's l1: 2809.97
# [300]	valid's l1: 2879.69
# Early stopping, best iteration is:
# [126]	valid's l1: 2751.76
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2932.16
# [200]	valid's l1: 3126.96
# Early stopping, best iteration is:
# [98]	valid's l1: 2905.11
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2789.21
# [200]	valid's l1: 2852.11
# [300]	valid's l1: 2928.18
# Early stopping, best iteration is:
# [121]	valid's l1: 2766.54
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2791.47
# [200]	valid's l1: 2876.13
# [300]	valid's l1: 2931.09
# Early stopping, best iteration is:
# [120]	valid's l1: 2771.31
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2806.83
# [200]	valid's l1: 2834.46
# [300]	valid's l1: 2866.58
# Early stopping, best iteration is:
# [155]	valid's l1: 2783.25
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2956.94
# [200]	valid's l1: 3129.79
# Early stopping, best iteration is:
# [96]	valid's l1: 2917.36
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2901.53
# [200]	valid's l1: 3021.49
# Early stopping, best iteration is:
# [98]	valid's l1: 2863.4
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 3039.86
# [200]	valid's l1: 3236.65
# Early stopping, best iteration is:
# [97]	valid's l1: 2989.07
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2813.38
# [200]	valid's l1: 2872.96
# [300]	valid's l1: 2916.19
# Early stopping, best iteration is:
# [121]	valid's l1: 2794.65
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2812.84
# [200]	valid's l1: 2836.54
# [300]	valid's l1: 2882.98
# Early stopping, best iteration is:
# [154]	valid's l1: 2780.57
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2923.6
# [200]	valid's l1: 3043.48
# Early stopping, best iteration is:
# [99]	valid's l1: 2877.97
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2795.91
# [200]	valid's l1: 2839.68
# [300]	valid's l1: 2915.67
# Early stopping, best iteration is:
# [121]	valid's l1: 2766.81
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2793.29
# [200]	valid's l1: 2843.95
# [300]	valid's l1: 2906.02
# Early stopping, best iteration is:
# [120]	valid's l1: 2769.9
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2853.98
# [200]	valid's l1: 2883.87
# [300]	valid's l1: 2952.55
# Early stopping, best iteration is:
# [121]	valid's l1: 2828.15
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 3183.67
# [200]	valid's l1: 3512.11
# Early stopping, best iteration is:
# [96]	valid's l1: 3153.51
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 3180.13
# [200]	valid's l1: 3375.86
# Early stopping, best iteration is:
# [77]	valid's l1: 3114.5
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2793.04
# [200]	valid's l1: 2819.28
# [300]	valid's l1: 2872.47
# Early stopping, best iteration is:
# [117]	valid's l1: 2779.66
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 3191.19
# [200]	valid's l1: 3419.68
# Early stopping, best iteration is:
# [98]	valid's l1: 3153.68
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2939.5
# [200]	valid's l1: 3075.13
# [300]	valid's l1: 3106.69
# Early stopping, best iteration is:
# [121]	valid's l1: 2905.88
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 3012.71
# [200]	valid's l1: 3186.96
# Early stopping, best iteration is:
# [95]	valid's l1: 2969.85
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2823.6
# [200]	valid's l1: 2882.93
# [300]	valid's l1: 2979.84
# Early stopping, best iteration is:
# [121]	valid's l1: 2802.41
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 3273.49
# [200]	valid's l1: 3339.73
# [300]	valid's l1: 3447.66
# Early stopping, best iteration is:
# [120]	valid's l1: 3224.6
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2778.68
# [200]	valid's l1: 2797.38
# [300]	valid's l1: 2916.29
# Early stopping, best iteration is:
# [124]	valid's l1: 2747.35
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2780.97
# [200]	valid's l1: 2840.71
# [300]	valid's l1: 2911.29
# Early stopping, best iteration is:
# [118]	valid's l1: 2755.98
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2766.82
# [200]	valid's l1: 2802.42
# [300]	valid's l1: 2860.76
# Early stopping, best iteration is:
# [119]	valid's l1: 2740.97
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2779.59
# [200]	valid's l1: 2861.51
# [300]	valid's l1: 2925.14
# Early stopping, best iteration is:
# [111]	valid's l1: 2765.55
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2788.09
# [200]	valid's l1: 2854.46
# [300]	valid's l1: 2913.79
# Early stopping, best iteration is:
# [111]	valid's l1: 2765.91
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2772.03
# [200]	valid's l1: 2855.13
# [300]	valid's l1: 2930.53
# Early stopping, best iteration is:
# [105]	valid's l1: 2764.88
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2752.42
# [200]	valid's l1: 2809.53
# [300]	valid's l1: 2909.77
# Early stopping, best iteration is:
# [111]	valid's l1: 2738.03
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2762.26
# [200]	valid's l1: 2834.32
# [300]	valid's l1: 2926.63
# Early stopping, best iteration is:
# [104]	valid's l1: 2755.24
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2786.73
# [200]	valid's l1: 2849.69
# [300]	valid's l1: 2954.19
# Early stopping, best iteration is:
# [115]	valid's l1: 2777.7
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2811.89
# [200]	valid's l1: 2885.38
# [300]	valid's l1: 2984.46
# Early stopping, best iteration is:
# [116]	valid's l1: 2793.1
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2776.19
# [200]	valid's l1: 2905.61
# [300]	valid's l1: 3009.98
# Early stopping, best iteration is:
# [111]	valid's l1: 2763.32
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2799.29
# [200]	valid's l1: 2850.4
# [300]	valid's l1: 2912.05
# Early stopping, best iteration is:
# [121]	valid's l1: 2777.71
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2764.55
# [200]	valid's l1: 2876.14
# Early stopping, best iteration is:
# [99]	valid's l1: 2754.84
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2797.88
# [200]	valid's l1: 2840.12
# Early stopping, best iteration is:
# [98]	valid's l1: 2777.73
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2774.15
# [200]	valid's l1: 2861.16
# [300]	valid's l1: 2946.68
# Early stopping, best iteration is:
# [109]	valid's l1: 2760.06
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2829.87
# [200]	valid's l1: 2959.97
# [300]	valid's l1: 3083.04
# Early stopping, best iteration is:
# [111]	valid's l1: 2817.07
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2814.56
# [200]	valid's l1: 2973.16
# Early stopping, best iteration is:
# [96]	valid's l1: 2803.53
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2789.79
# [200]	valid's l1: 2899.98
# [300]	valid's l1: 3006.64
# Early stopping, best iteration is:
# [121]	valid's l1: 2783.25
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2784.68
# [200]	valid's l1: 2819.46
# Early stopping, best iteration is:
# [90]	valid's l1: 2765.38
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2787.49
# [200]	valid's l1: 2889.01
# [300]	valid's l1: 2969.92
# Early stopping, best iteration is:
# [107]	valid's l1: 2777.64
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2790.54
# [200]	valid's l1: 2893.19
# [300]	valid's l1: 2976.29
# Early stopping, best iteration is:
# [111]	valid's l1: 2768.81
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2805.92
# [200]	valid's l1: 2898.78
# [300]	valid's l1: 3012.67
# Early stopping, best iteration is:
# [111]	valid's l1: 2790.01
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 3092.08
# [200]	valid's l1: 3436.5
# Early stopping, best iteration is:
# [97]	valid's l1: 3059.44
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2801.36
# [200]	valid's l1: 2973.06
# [300]	valid's l1: 3145.51
# Early stopping, best iteration is:
# [111]	valid's l1: 2789.55
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 3001.53
# [200]	valid's l1: 3310.88
# Early stopping, best iteration is:
# [97]	valid's l1: 2960.06
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2786.98
# [200]	valid's l1: 2816.01
# [300]	valid's l1: 2906.11
# Early stopping, best iteration is:
# [111]	valid's l1: 2770.85
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2803.13
# [200]	valid's l1: 2871.46
# [300]	valid's l1: 2990.29
# Early stopping, best iteration is:
# [111]	valid's l1: 2789.15
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2768.76
# [200]	valid's l1: 2925.19
# [300]	valid's l1: 3039.45
# Early stopping, best iteration is:
# [111]	valid's l1: 2758.51
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2796.88
# [200]	valid's l1: 2825.28
# [300]	valid's l1: 2898.61
# Early stopping, best iteration is:
# [119]	valid's l1: 2766.55
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2773.99
# [200]	valid's l1: 2980.1
# [300]	valid's l1: 3120.62
# Early stopping, best iteration is:
# [109]	valid's l1: 2762.38
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 3324.36
# [200]	valid's l1: 4015.36
# Early stopping, best iteration is:
# [67]	valid's l1: 3228.21
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's l1: 2774.59
# [200]	valid's l1: 2805.05
# [300]	valid's l1: 2857.12
# Early stopping, best iteration is:
# [111]	valid's l1: 2759.32
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's l1: 2838.75
# Early stopping, best iteration is:
# [61]	valid's l1: 2767.44
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's l1: 5056.43
# Early stopping, best iteration is:
# [54]	valid's l1: 4726.44
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's l1: 2035.9
# Early stopping, best iteration is:
# [87]	valid's l1: 2019
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's l1: 2086.89
# Early stopping, best iteration is:
# [73]	valid's l1: 2041.11
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's l1: 2702.68
# Early stopping, best iteration is:
# [46]	valid's l1: 2557.93
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Time left 257.5471155643463
# Blending: Optimization starts with equal weights and score -3249.048918027224
# Blending, iter 0: score = -2822.382128760489, weights = [0. 0. 1.]
# Blending, iter 1: score = -2822.382128760489, weights = [0. 0. 1.]
# No score update. Terminated
#
# Automl preset training completed in 342.50 seconds.

# %%
valid_pred = automl.predict(df_test)

# %% [markdown]
# mean_absolute_error(X_train['final_price'], oof_pred.data[:,0])

# %% [markdown]
# mean_absolute_error(X_valid['final_price'], valid_pred.data[:,0])

# %%
result = pd.DataFrame({'row_ID':df_test.index,'final_price':valid_pred.data[:,0]})
result
# Out:
#        row_ID   final_price
# 0       35000   3061.352539
# 1       35001   5917.295898
# 2       35002   5238.629395
# 3       35003   5847.614258
# 4       35004   3675.278076
# ...       ...           ...
# 10692   45692   2512.460693
# 10693   45693   1520.724854
# 10694   45694  14976.219727
# 10695   45695   4865.946289
# 10696   45696   6508.689941
#
# [10697 rows x 2 columns]

# %%
result.to_csv('submis_automl.csv', index=False)
